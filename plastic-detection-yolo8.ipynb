# %%
# %matplotlib inline

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import cv2
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# Loaв YOLOv8 model 
model = YOLO('yolov8n.pt')  
# Train model
data_path = os.path.abspath('data_yolo/data.yaml')
model.train(
    data=data_path,        
    epochs=50,                         
    imgsz=128,                         
    batch=-1                           
)
# Out:
# Ultralytics 8.3.53  Python-3.10.16 torch-2.5.1+cpu CPU (Intel Core(TM) i7-7700HQ 2.80GHz)
# ...

# %%
# Load and preprocess the test image
image_path = "result_with_detections.jpg"  # Path to your test image
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Run inference
results = model.predict(source=image_path, save=False, show=False)

# Extract predictions
detections = results[0].boxes.xyxy.numpy()  # Bounding boxes (x1, y1, x2, y2)
scores = results[0].boxes.conf.numpy()     # Confidence scores
classes = results[0].boxes.cls.numpy()     # Class IDs
# Out:
# image 1/1 C:\Users\Master\CV_GPU\plastic-waste-1.jpg: 96x128 (no detections), 16.3ms
# Speed: 12.6ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 96, 128)

# %%
import matplotlib.pyplot as plt
# Display results
for bbox, score, cls_id in zip(detections, scores, classes):
    x1, y1, x2, y2 = bbox
    label = f"{model.names[int(cls_id)]} {score:.2f}"
    cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
    cv2.putText(image, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Save the image with detections
output_path = "result_with_detections.jpg"  # Define output file path
# cv2.imwrite(output_path, image)  # Save the image

# %%
# Display the image with detections
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
import random
# Display 10 random 128x128 images from the dataset
def display_random_images(dataset_path):
    # Get all image file names from the dataset folder
    image_files = [f for f in os.listdir(dataset_path) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    if not image_files:
        print("No images found in the dataset folder. Please check the path.")
        return
    
    # Randomly select 10 images
    random_images = random.sample(image_files, min(10, len(image_files)))

    # Display the selected images
    plt.figure(figsize=(15, 15))
    for i, image_name in enumerate(random_images):
        image_path = os.path.join(dataset_path, image_name)
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue
        
        resized_image = cv2.resize(image, (128, 128))
        plt.subplot(2, 5, i + 1)
        plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
        plt.title(image_name)
        plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
display_random_images("data_yolo/dataset/images/train")
# Out:
# Randomly selected images: ['bottle-264-_JPG.rf.5e2cba8f39677e4be9e384235c69b024.jpg', 'bottle-31-_JPG.rf.f7a71db6cac2a7dcd9518635ca16adb2.jpg', '500632_jpg.rf.58025eff43afa2d501c2c1da5e746f11.jpg', 'bottle-288-_JPG.rf.7af8b6190df8e6c348f5074bb03b1f75.jpg', 'bottle-486-_JPG.rf.c52a9e5c79e78c9ac4e149937ea3f2cb.jpg', 'bottle-559-_JPG.rf.4edf6f9fc46b7b1b68ca9bb0e70acbb9.jpg', 'bottle-635-_JPG.rf.a028bbb554183870a9fc46be39eb0725.jpg', '200281_jpg.rf.72a54bdc8265c6528e1c97fd84a15955.jpg', 'bottle-367-_JPG.rf.4b983e280b78502521f36b1de63f58cd.jpg', 'bottle-275-_JPG.rf.a8277a9cdb32eb905d1a058ef0cd87b6.jpg']
